# %% [markdown]
# # Bib for external:

# %%
import os
import pandas as pd
import numpy as np
from scipy.stats import linregress
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import math
import sys
from dateutil.parser import parse

def find_exponents(df,
                   fractionToAnalyze=1,
                   outputPath='outputs',
                   outputTable=True,
                   outputPlots=True,
                   timescaling='mon', 
                   outputTablename='Testtable',
                   logToScreen=True,
                   columnFillThreshold=0.5,
                   exp_treshold=0.01,
                   r_treshold=0.9,
                   maxrows=5000):
    '''
    find and plot plot exponential data in a pandas dataframe

    :param dataframe df: The dataframe containing date-like and metric columns
    :param str fractionToAnalyze: The last xx percent (0.0-1.0) of data (indexed by the found date columns)
    :param str outputPath: The subfolder to write output table and plots to (created if not existing)
    :param bln outputTable: Write table to outputPath/table (True|False)
    :param bln outputPlots: Plot outputs to outputPath/plots (True|False)
    :param str timescaling: (sec|min|hour|day|mon|year) scaling the exponential factors to the given time unit
    :param str outputTablename: The table name used in the table, and the output plots
    :param bln logToScreen: Print out messages (True|False)
    :param dbl columnFillThreshold: filter out columns with more than xx percent (0.0-1.0) of the data missing
    :param dbl exp_treshold: only show and plot results with an exponent higher than x
    :param dbl r_treshold: only show and plot results with an R squared lower than x
    :param int maxrows: specify the maximum number of rows. If df.rowsize > maxrows a random sample of rows is used
    :return: A Pandas dataframe with a list of all date and metric column combinations with their exponential factor and R²
    :rtype: dataframe
    '''
    
    ############## To Do ###################
    # - Nina: Medium Blogpost and Statistics Paper (something like: https://www.dlr.de/sc/Portaldata/15/Resources/dokumente/pyhpc2011/submissions/pyhpc2011_submission_9.pdf)
    # - Mathias: Check with BMW for Open Source release
    # - Mathias: Create Mailing list for pip publishing
    # - Sebastian: The Exp values seem quite high. Do you know if this powerfit library gives back percentages or absolute values?
    # - Sebastian: Check if R (out of powerfit) is a good measure. shouldn't we use RMSE instead? you can search for ###TODO:sebastian:checkRMSE
    # - Sebastian: Improve error handling
    # - Sebastian: Test on publicly available data if we get errors and if error handling works as intended. 
    #              The goal is that errors don't stop the code execution, because we run it sequentially
    # - Sebastian: Publishing to Github
    # - Sebastian: Publishing to pip
    # - Sebastian: Habe hier noch einige Warnings, wo ich nicht weiß wo die herkommen:
    # C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
    # return (self.a < x) & (x < self.b)
    # C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
    # return (self.a < x) & (x < self.b)
    # C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
    # cond2 = cond0 & (x <= self.a)
    # C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
    # return (self.a < x) & (x < self.b)
    # C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
    # return (self.a < x) & (x < self.b)
    #######################################
    
    
    ######################## Functions: #########################
    def is_nan(x):
        return (x is np.nan or x != x)
    
    def printL(text):
        if logToScreen:
            print(text)
            
    def normalize(lst):
        minval=min(lst)
        maxval=max(lst)
        return [(float(i)-minval)/(maxval-minval) for i in lst]

    def powerfit(x, y):
        """line fitting on y-log scale"""

        slope, intercept, r, _, _=linregress(x,np.log(y))

        printL('slope: '+str(slope))
        printL('intercept:'+str(intercept))
        printL('r²:'+str(r))
        #k, m = np.polyfit(x, np.log(y), 1)
        return slope,intercept,r

    def cleanfilename(filename,cleanlist):
        text=filename
        for cleanword in cleanlist:
            text = text.replace(cleanword, '-')
        text=text.replace('-----','-')
        text=text.replace('----','-')
        text=text.replace('---','-')
        text=text.replace('--','-')
        text=text.replace('-','-')
        if text!=filename:
            printL("Warning: Provided filename '"+filename+"' is invalid. Set to '"+text+"'")
        return text
    
    def checkAndGetBool(val):
        if isinstance(val, str):
            return val.lower() in ['true', '1', 't', 'y', 'yes']
        if isinstance(val, (int, float)):
            if val>=1:
                return 1
            else:
                return 0

        
    ############################ Input handling: #############################
    data=df
    ##### Input handling: logToScreen ###
    logToScreen=checkAndGetBool(logToScreen)
    #### Input handling: maxrows ##############  
    if maxrows<=0:
        rownum=df.shape[0]
        maxrows=min(rownum,5000)
        printL("Warning: maxrows cannot be <1. Set to " + str(rownum))
        
    ##### Input handling: df ###################
    if df is None:
        printL("Warning: Dataframe is empty. Returning None")
        return None
    if df.shape[0]==0:
        printL("Warning: Dataframe is empty. Returning None")
        return None    
    if df.shape[0]>maxrows:
        data=data.sample(maxrows)
        
    ##### Input handling: fractionToAnalyze ###  
    ##### ensure that the fraction is between 0 and 1:   
    if fractionToAnalyze>1:
        printL("Warning: Fraction to analyze was specified > 1 ! Set to 1" )
        fractionToAnalyze=1
    if fractionToAnalyze<=0:
        printL("Warning: Fraction to analyze was specified <= 0 ! Set to 0.1" )
        fractionToAnalyze=0.1
        
    ##### Input handling: outputPath ###  
    ####ensure that output folders exist:
    if outputPlots:
        
        if not os.path.exists(".\\"+outputPath):
            os.makedirs(".\\"+outputPath)
        if not os.path.exists(".\\"+outputPath+"\\plots"):
            os.makedirs(".\\"+outputPath+"\\plots")
    if outputTable:
        if not os.path.exists(".\\"+outputPath):
            os.makedirs(".\\"+outputPath)
        if not os.path.exists(".\\"+outputPath+"\\table"):
            os.makedirs(".\\"+outputPath+"\\table")

    ##### Input handling: outputTable ###
    outputTable=checkAndGetBool(outputTable)

    ##### Input handling: outputPlots ###
    outputPlots=checkAndGetBool(outputPlots)
    
    ##### Input handling: timescaling ###
    if timescaling in ['sec','s','seconds','se','second']:
        timeScalingDivisor=1000
    elif timescaling in ['min','mi','minutes','minute']:
        timeScalingDivisor=1000*60
    elif timescaling in ['hour','h','ho','hou','hours']:
        timeScalingDivisor=1000*60*60    
    elif timescaling in ['day','d','da','days']:
        timeScalingDivisor=1000*60*60*24
    elif timescaling in ['mon','mo','month','months']:
        timeScalingDivisor=1000*60*60*24*30.4366666666
    elif timescaling in ['year','yea','ye','y','years']:
        timeScalingDivisor=1000*60*60*24*30.4366666666*365
    else:
        printL("Warning: No valid timescaling provided (sec|min|hour|day|mon|year). Set to month.")
    
    ##### Input handling: outputTablename ###
    if outputTablename is None:
        printL("Warning: No valid outputTableName provided. As it is used for file naming, 'testtable' is used.")
        outputTablename="testtable"
        
    ##### Input handling: columnFillThreshold ###
    if columnFillThreshold>1:
        printL("Warning: columnFillThreshold was specified > 1 ! Set to 1" )
        columnFillThreshold=1
    if columnFillThreshold<=0:
        printL("Warning: columnFillThreshold was specified <= 0 ! Set to 0.1" )
        columnFillThreshold=0.1

        
        
    ############################ Code: #############################
      
    
    #### specify the columns of the returntable:
    resulttablecols=['tablename','datecol','valuecol','analyzed_fraction','exponent','r_squared'] 
    
    printL ('######## Starting ' + outputTablename + ' ###### fraction '+str(fractionToAnalyze)+'########')
    printL ('##########################################')
    
    #### specify which column types are regarded as numeric (and get analyzed):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    
    #### specify which chars to remove in the filenames:
    cleanlist=['(',')',' ',':','[',']','#','/']  
    

    #### initialize an empty data frame with the columns for returning the results:
    df_result = pd.DataFrame(columns=resulttablecols)
    
    #### Loop through all datetimecols:
    for datetimecol in data.columns: 
        df_temp=data.copy()

             
        ### identify date columns and append as converted column (datetime) and converted2 (numeric - for correlation)
        
        if any(df_temp[datetimecol].astype(str).str.len()<4):
            printL("####### The datetime column "+ datetimecol+": has less than 4 chars --> not used as datetime column.")
            continue
        try:
            df_temp['date_converted']=pd.to_datetime(df_temp[datetimecol])
            df_temp['date_converted2']=mdates.date2num(df_temp['date_converted'])
        except:
            printL("####### Datetime column "+ datetimecol+": conversion error!")
            continue
        if any(df_temp['date_converted'] < '1990-01-01'):
            printL("####### The datetime column "+ datetimecol+" had values before 2000-01-01 --> not used as date")
            continue
        if datetimecol!='date_converted':
            printL("####### The datetime column: "+ datetimecol + " is used as datetimecol!")

            
        ### filter columns where only 50% of the rows have values:
        df_temp= df_temp.loc[:, df_temp.isnull().mean() < columnFillThreshold]
        
        ### Only use the last fraction of the data, indexed / determined by the time column at hand:
        maxval=max(df_temp['date_converted2']) #use converted time columns to allow for easy multiplication
        minval=min(df_temp['date_converted2'])
        timepoint_to_cut=(maxval-minval)*(1-fractionToAnalyze)+minval
        df_temp=df_temp[(df_temp['date_converted2'] > timepoint_to_cut)]
 
        ###loop through all numeric cols:
        for numericcol in data.select_dtypes(include=numerics).columns:
            if numericcol==datetimecol or numericcol not in df_temp.columns:
                continue ###skip this column if it is the date col
            try:
                #### zero values will break the algorithm with log calculations. 
                #### Therefore, we move all data points slightly above 0.
                #### 'slightly" is defined as min_max_diff/100000

                min_max_diff=max(df_temp[numericcol])-min(df_temp[numericcol])
                min0=False
                if min(df_temp[numericcol])==0:
                       min0=True
                shiftamount=min_max_diff/100000
                #### Start computing the values:
                printL('##### Computing numeric col: '+ numericcol)
                printL('##### Date col: '+datetimecol)
                cols_to_keep=['date_converted','date_converted2',datetimecol,numericcol]
                df_temp_2=df_temp[cols_to_keep].copy()# this df is used for cleaning and afterwards splitted
                #remove all rows with nan or inf:
                df_temp_2=df_temp_2.replace([np.inf, -np.inf], np.nan)
                df_temp_2=df_temp_2.dropna(subset=[numericcol])
                df_temp_2=df_temp_2.sort_values(['date_converted'],ascending=True)

                #now get minimum val, and move all points if negative:
                minval=min(df_temp_2[numericcol])


                #df_temp_2 is used for the regular plot, df_temp_3 is used for log calculations/plots (values are moved here):
                df_temp_3=df_temp_2
                if minval<=0:
                    df_temp_3[numericcol]=df_temp_3[numericcol]+shiftamount 
                    df_temp_3[numericcol]=df_temp_3[numericcol]-minval
                    printL('! moved by '+str(minval) +' to correct for negative values')


                x=df_temp_3['date_converted2']
                y=df_temp_3[numericcol]
                datetime=df_temp_3['date_converted']#datetime




                #### fit a regression line and get the slope (= exponential factor):
                slope,intercept,r=powerfit(x,y)   ###TODO:sebastian:checkRMSE
                y_lin = slope*x + intercept
                
                r=abs(r)
                slope=slope*timeScalingDivisor
                if r<r_treshold or slope<exp_treshold or is_nan(r) or is_nan(slope):
                    continue

                #append to output table:
                df_result=df_result.append(pd.Series([outputTablename,datetimecol,numericcol,fractionToAnalyze,slope,r],index=resulttablecols),ignore_index=True)
                if outputTable:
                    df_result.to_csv(outputPath+'/table/'+cleanfilename(outputTablename+"-"+str(int(round(fractionToAnalyze*100,0)))+"perc.csv",cleanlist))
                    
                    
                ################################### Plotting #########################################

                if outputPlots:
                    ########### Plotparameters:
                    figsize_plot=(11,5) #inches
                    fontsize_plot=12
                    linestyle='-'#'--'
                    linewidth_plot=2
                    ############################ Plot 1: Logarithmized - Dev ############################
                    fig, ax = plt.subplots(figsize=figsize_plot)
                    plt.plot(datetime, y,'.', alpha=.3,color="#3e5463") #plotting the values

                    ##exp to all y values: 
                    ys_exp = [math.exp(x) for x in y_lin]

                    plt.plot(datetime,ys_exp,linestyle, linewidth=linewidth_plot,color='#F38d00') #plotting the line

                    #plotting additional information:
                    plt.annotate("ex="+str(round(slope,4)), xy=(0.95,0.95),xycoords='axes fraction',
                     fontsize=fontsize_plot)
                    plt.annotate("r²="+str(round(r,4)), xy=(0.95,0.90),xycoords='axes fraction',
                     fontsize=fontsize_plot)
                    plt.title(datetimecol+"~"+numericcol + " (fraction: last "+str(100*fractionToAnalyze)+"%)", fontsize=14)
                    plt.yscale('log')
                    if min0: #only set min y axis if 0 values are existing:
                        x1,x2,y1,y2 = plt.axis()
                        plt.axis((x1,x2,shiftamount/10,y2))
                        #plt.annotate("0 (no log)", xy=(-0.005,shiftamount),xycoords=('axes fraction','data'),fontsize=fontsize_plot,color='red',ha='right')

                    plt.xticks(rotation=90)
                    ax.spines['right'].set_visible(False)
                    ax.spines['top'].set_visible(False)
                    plt.savefig(outputPath+'/plots/'+cleanfilename(outputTablename+'-'+datetimecol+'-'+numericcol,cleanlist)+
                                '-'+str(int(round(fractionToAnalyze*100,0)))+'perc-log.png')
                    plt.close('all')

                ############################ Plot 2: Regular Plot - Dev ############################
                    fig, ax = plt.subplots(figsize=figsize_plot)

                    plt.plot(datetime, y,'.', alpha=.3,color="#3e5463") #plotting the values

                    plt.plot(datetime,ys_exp,linestyle, linewidth=linewidth_plot,color='#F38d00') #plotting the line

                    #plotting additional information:
                    plt.annotate("ex="+str(round(slope,4)), xy=(0.95,0.95),xycoords='axes fraction',
                     fontsize=fontsize_plot)
                    plt.annotate("r²="+str(round(r,4)), xy=(0.95,0.90),xycoords='axes fraction',
                     fontsize=fontsize_plot)
                    plt.title(datetimecol+"~"+numericcol + " (fraction: last "+str(100*fractionToAnalyze)+"%)", fontsize=14)
                    if min0: #only set min y axis if 0 values are existing:
                        x1,x2,y1,y2 = plt.axis()
                        plt.axis((x1,x2,shiftamount/10,y2))
                        #plt.annotate("0", xy=(-0.005,shiftamount),xycoords=('axes fraction','data'),fontsize=fontsize_plot,color='red',ha='right')

                    plt.xticks(rotation=90)
                    ax.spines['right'].set_visible(False)
                    ax.spines['top'].set_visible(False)

                    plt.savefig(outputPath+'/plots/'+cleanfilename(outputTablename+'-'+datetimecol+'-'+numericcol,cleanlist)+
                                '-'+str(int(round(fractionToAnalyze*100,0)))+'perc-nonlog.png')
                    plt.close('all')

            except:
                printL("Unexpected error:" + str(sys.exc_info()[0]))
    if df_result.shape[0]>0: ##only append if there are results:
        ##finally create a combined score for easy sorting:

        #exponent_scaled = normalize(list(df_result['exponent']))

        #r² is already scaled, but we want a higher score for lower r values:
        #r_prepared=1-r #a low r should lead to a higher score
        #it is much more important, that is is a power law (low r²), a high exponent is rather secondary --> weight
        #weight_factor_exponent=100
       
        #sort_score=[(weight_factor_exponent*r_prepared+x)/(weight_factor_exponent+1) for x in exponent_scaled]
        #df_result['sort_score']=sort_score
        df_result=df_result.sort_values(['exponent'],ascending=False)     

    return(df_result)

# %% [markdown]
# # Examples

# %% [markdown]
# ## loading testdata in a dataframe

# %%
#sqlDFTest = spark.sql("SELECT * FROM db_prepared_bdas_rsu_local_e2e.bt_tal_main limit 10")
#sqlDF.show(1)
#sqlDFTest = spark.sql("select * from db_source_gwk_local.v_bdgwk_t_gw_antrep_gut where rand() <= 0.0001 distribute by rand() sort by rand() limit 1000")
sqlDFTest=pd.read_csv("db_source_gwk_local.v_bdgwk_t_gw_antrep_gut.csv",sep=";")
sqlDFTest.head(2)
# Out:
#    Unnamed: 0    antrag_id       gutschriftsdatum  line_nr  version  \
# 0           0  241391683.0  2016-05-07 00:00:00.0      2.0      2.0
# 1           1  191737063.0  2011-09-24 00:00:00.0      3.0      2.0
#
#    ist_lokale_reparatur  gw_kulanzstufe  gw_kulanzstufe_lokal  \
# 0                     0               7                   7.0
# 1                     0               7                   NaN
#
#    gw_kulanzstufe_zentral  mixed_stage  ...  vfc_id_fl_fzg vfc_id_fa  \
# 0                     7.0          0.0  ...            NaN       NaN
# 1                     7.0          0.0  ...            NaN       NaN
#
#   vfc_id_fbed fb_typ_id_fo fb_typ_id_fl_ort fb_typ_id_fl_fzg fb_typ_id_fa  \
# 0         NaN         FO_K              NaN              NaN          NaN
# 1         NaN         FO_K              NaN              NaN          NaN
#
#   fb_typ_id_fbed        erfassungsdatum  deltakey_ts
# 0            NaN  2012-11-16 00:00:00.0   2016-05-07
# 1            NaN  2012-11-16 00:00:00.0   2011-09-25
#
# [2 rows x 187 columns]

# %% [markdown]
# ## Run the function on the test data:

# %%
resulttable=find_exponents(sqlDFTest,
                           fractionToAnalyze=1,
                           outputPath='outputs',
                           outputTable=True,
                           outputPlots=True,
                           outputTablename='Testtable',
                           logToScreen=True,
                           columnFillThreshold=0.5,
                           exp_treshold=0.1,
                           r_treshold=0.7,
                           maxrows=5000)


resulttable
# Out:
# ######## Starting Testtable ###### fraction 0.3########
# ##########################################
# ####### The datetime column Unnamed: 0: has less than 4 chars --> not used as datetime column.
# ####### The datetime column antrag_id had values before 2000-01-01 --> not used as date
# ####### The datetime column: gutschriftsdatum is used as datetimecol!
# 734138.0
# 737036.0
# 736166.6
# (1000, 141)
# (409, 141)
# ##### Computing numeric col: Unnamed: 0
# ##### Date col: gutschriftsdatum
# slope: -1.683714421366873e-05
# intercept:18.283698926280245
# r²:-0.004354587359007977
# ##### Computing numeric col: antrag_id
# ##### Date col: gutschriftsdatum
# slope: 0.00015468709457285563
# intercept:-94.56397184190197
# r²:0.9989080339925134
# ##### Computing numeric col: line_nr
# ##### Date col: gutschriftsdatum
# slope: -0.00014547970901803646
# intercept:107.74773863323368
# r²:-0.0585687678238649
# ##### Computing numeric col: version
# ##### Date col: gutschriftsdatum
# slope: -5.593283672200104e-05
# intercept:41.767453325985045
# r²:-0.037615085901312836
# ##### Computing numeric col: ist_lokale_reparatur
# ##### Date col: gutschriftsdatum
# ! moved by 0 to correct for negative values
# slope: -0.0005898373329734331
# intercept:427.86351850513927
# r²:-0.02650157692985919
# ##### Computing numeric col: gw_kulanzstufe
# ##### Date col: gutschriftsdatum
# slope: -8.279322963671847e-05
# intercept:62.41550825991872
# r²:-0.02398533547357301
# ##### Computing numeric col: gw_kulanzstufe_lokal
# ##### Date col: gutschriftsdatum
# slope: -3.095547576696893e-05
# intercept:24.228846063815418
# r²:-0.008955529913781079
# ##### Computing numeric col: gw_kulanzstufe_zentral
# ##### Date col: gutschriftsdatum
# slope: -7.40048897263188e-05
# intercept:55.93965854510608
# r²:-0.021406427187755532
# ##### Computing numeric col: mixed_stage
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.00040878923348373306
# intercept:-312.47991546759323
# r²:0.08007484332854783
# ##### Computing numeric col: fahrzeugart
# ##### Date col: gutschriftsdatum
# ! moved by 0 to correct for negative values
# slope: -0.00016390333096174612
# intercept:120.5635158999093
# r²:-0.030283610110442914
# ##### Computing numeric col: freigabe_angewendet
# ##### Date col: gutschriftsdatum
# ! moved by 0 to correct for negative values
# slope: -4.613053015351969e-06
# intercept:-8.058618691565105
# r²:-0.0014690083285797892
# ##### Computing numeric col: ist_best_reparatur
# ##### Date col: gutschriftsdatum
# ! moved by 0 to correct for negative values
# slope: -0.0014542891647820703
# intercept:1067.1022104826839
# r²:-0.06732703205710883
# ##### Computing numeric col: mixed_repair
# ##### Date col: gutschriftsdatum
# ! moved by 0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: hoechstwert_id_vg
# ##### Date col: gutschriftsdatum
# slope: -0.0006634774795994272
# intercept:500.7366206567577
# r²:-0.055045335780161984
# ##### Computing numeric col: hoechstwert_id_ag
# ##### Date col: gutschriftsdatum
# slope: 0.0006855209089247816
# intercept:-497.60495347510107
# r²:0.02758338982434933
# ##### Computing numeric col: hoechstwert_id_res
# ##### Date col: gutschriftsdatum
# slope: 0.0
# intercept:0.0
# r²:0.0
# ##### Computing numeric col: hoechstwert_id_ext
# ##### Date col: gutschriftsdatum
# slope: 0.0
# intercept:0.0
# r²:0.0
# ##### Computing numeric col: hoechstwert_id_mvg
# ##### Date col: gutschriftsdatum
# slope: 0.0001724230772839138
# intercept:-126.94045393658374
# r²:0.04719230993915473
# ##### Computing numeric col: ag_fallzaehler
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0001809065982233966
# intercept:127.88068520255304
# r²:-0.008054850635433946
# ##### Computing numeric col: ag_anz_teile
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0001185463062025278
# intercept:83.0881228270046
# r²:-0.007841529567387895
# ##### Computing numeric col: ag_sum_az
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.00044885089232448485
# intercept:-339.173467224368
# r²:0.06340254149837173
# ##### Computing numeric col: ag_sum_aw_p_az
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:60: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# slope: -0.00018277385435147705
# intercept:132.0983679046019
# r²:-0.01017944270185537
# ##### Computing numeric col: ag_kost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by -4.71 to correct for negative values
# slope: -0.00010564921260426873
# intercept:80.92053729493287
# r²:-0.016008895726879555
# ##### Computing numeric col: ag_kost_aw_p_az_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00015134643719187543
# intercept:111.01609584496597
# r²:-0.009164191744126363
# ##### Computing numeric col: ag_kost_aw_p_az_ust_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0005260848220185409
# intercept:379.69689104025827
# r²:-0.09174922413282548
# ##### Computing numeric col: ag_kost_aw_p_az_netto_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00014436755587237545
# intercept:105.87244986809951
# r²:-0.008748254206803677
# ##### Computing numeric col: ag_teilekost_m_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00020777258102664564
# intercept:151.73157114586778
# r²:-0.012645906087305491
# ##### Computing numeric col: ag_teilekost_m_nk_ust_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00022590764939347456
# intercept:160.05777378519127
# r²:-0.04149776243419135
# ##### Computing numeric col: ag_teilekost_m_nk_netto_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00020481171931745705
# intercept:149.54765537834456
# r²:-0.012478206052086695
# ##### Computing numeric col: ag_teilekost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00022037416166404883
# intercept:160.73899695652648
# r²:-0.013189023083816323
# ##### Computing numeric col: ag_teilekost_rs_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 4.786399064644431e-05
# intercept:-43.61450348521453
# r²:0.020734510719818005
# ##### Computing numeric col: ag_hc_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.00015782412938613455
# intercept:-120.38277018741698
# r²:0.012355581286697776
# ##### Computing numeric col: ag_hc_kost_ust_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -3.511739384885154e-05
# intercept:17.324862993743743
# r²:-0.007314625730821558
# ##### Computing numeric col: ag_hc_kost_netto_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.00015958653510309885
# intercept:-121.68359823424821
# r²:0.012514005201588345
# ##### Computing numeric col: ag_lc_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -5.2996345464531255e-05
# intercept:33.552458814788984
# r²:-0.004362626017640423
# ##### Computing numeric col: ag_lc_kost_ust_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -4.153327374075791e-05
# intercept:21.929782183624187
# r²:-0.008566120995554097
# ##### Computing numeric col: ag_lc_kost_netto_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -5.12636176528063e-05
# intercept:32.27349507066938
# r²:-0.0042291674543754225
# ##### Computing numeric col: ag_lc_kost_ust_basis_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -4.0976846023742086e-05
# intercept:23.292304615117096
# r²:-0.008431363192892788
# ##### Computing numeric col: ag_lc_kost_keine_ust_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -1.207468657621931e-05
# intercept:3.2479583643638055
# r²:-0.001058497644650268
# ##### Computing numeric col: ag_fremdl_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -4.71 to correct for negative values
# slope: -0.00021478769946237122
# intercept:160.01252483852565
# r²:-0.06216807010558698
# ##### Computing numeric col: ag_fremdl_kost_ust_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -3.2178016265258626e-05
# intercept:16.828447732159702
# r²:-0.012013960970086397
# ##### Computing numeric col: ag_fremdl_kost_netto_eur
# ##### Date col: gutschriftsdatum
# ! moved by -4.71 to correct for negative values
# slope: -0.00021319696580224208
# intercept:158.83954975991927
# r²:-0.06166472276657617
# ##### Computing numeric col: ag_reparaturkost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -4.71 to correct for negative values
# slope: -0.00011743405024331461
# intercept:89.63072968126224
# r²:-0.01744232828371624
# ##### Computing numeric col: ag_reparaturkost_ust_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00037621028007986173
# intercept:271.00703195064364
# r²:-0.06323595689375029
# ##### Computing numeric col: ag_reparaturkost_netto_eur
# ##### Date col: gutschriftsdatum
# ! moved by -4.71 to correct for negative values
# slope: -0.00011290086821759666
# intercept:86.28834012871833
# r²:-0.016813262768446496
# ##### Computing numeric col: ag_neben_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -2.3804791077186885e-05
# intercept:13.677963066887296
# r²:-0.0017919217580969191
# ##### Computing numeric col: ag_plop_eur
# ##### Date col: gutschriftsdatum
# ! moved by -30.05 to correct for negative values
# slope: 2.2467875303088094e-05
# intercept:-12.945648196996151
# r²:0.00844225871100646
# ##### Computing numeric col: ag_kost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by -4.99 to correct for negative values
# slope: 0.00044944053640597325
# intercept:-326.406330506564
# r²:0.04912069795194673
# ##### Computing numeric col: ag_kost_aw_p_az_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.0005936889652145439
# intercept:-434.1406735101577
# r²:0.05750117726239224
# ##### Computing numeric col: ag_kost_aw_p_az_ust_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0005138311120866043
# intercept:372.7136427645704
# r²:-0.09072678471932887
# ##### Computing numeric col: ag_kost_aw_p_az_netto_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.0006005746178560585
# intercept:-439.21561763700777
# r²:0.058239463977607375
# ##### Computing numeric col: ag_teilekost_m_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.00029105159855929183
# intercept:-210.49126196585888
# r²:0.03695174829026158
# ##### Computing numeric col: ag_teilekost_m_nk_ust_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.000213968140770549
# intercept:153.30631923264744
# r²:-0.03984702760004079
# ##### Computing numeric col: ag_teilekost_m_nk_netto_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.00029315840709803764
# intercept:-212.04587629405665
# r²:0.03729573136793719
# ##### Computing numeric col: ag_teilekost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.000295059536054513
# intercept:-213.68387661478766
# r²:0.03689403111259864
# ##### Computing numeric col: ag_teilekost_rs_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 4.786399064644431e-05
# intercept:-43.61450348521453
# r²:0.020734510719818005
# ##### Computing numeric col: ag_hc_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 8.540432257352213e-05
# intercept:-61.57657991245136
# r²:0.013234570574691318
# ##### Computing numeric col: ag_hc_kost_ust_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -3.332398610964572e-05
# intercept:18.049524527507987
# r²:-0.006960402462552671
# ##### Computing numeric col: ag_hc_kost_netto_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 8.638235854615403e-05
# intercept:-62.29945110726653
# r²:0.013427643359710625
# ##### Computing numeric col: ag_lc_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 1.3451950350303483e-05
# intercept:-8.68492419520623
# r²:0.0022086195659778356
# ##### Computing numeric col: ag_lc_kost_ust_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -4.047931970680334e-05
# intercept:23.19949550621252
# r²:-0.008368103158296832
# ##### Computing numeric col: ag_lc_kost_netto_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 1.4460387154836131e-05
# intercept:-9.430190248982917
# r²:0.002382670290915386
# ##### Computing numeric col: ag_lc_kost_ust_basis_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -3.891945248932769e-05
# intercept:23.822709147814248
# r²:-0.008031575360926739
# ##### Computing numeric col: ag_lc_kost_keine_ust_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -5.849871040695097e-07
# intercept:1.5887993041009016
# r²:-0.00010118502458218633
# ##### Computing numeric col: ag_fremdl_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -4.99 to correct for negative values
# slope: -0.00012778765633709817
# intercept:96.38531196706295
# r²:-0.022152132685857678
# ##### Computing numeric col: ag_fremdl_kost_ust_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -3.195588782821971e-05
# intercept:18.65498312212456
# r²:-0.011919130750062741
# ##### Computing numeric col: ag_fremdl_kost_netto_lw
# ##### Date col: gutschriftsdatum
# ! moved by -4.99 to correct for negative values
# slope: -0.00012766477937113422
# intercept:96.29407197306746
# r²:-0.02216395424443128
# ##### Computing numeric col: ag_reparaturkost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -4.99 to correct for negative values
# slope: 0.00044040060593724355
# intercept:-319.61560409181743
# r²:0.048933572954203
# ##### Computing numeric col: ag_reparaturkost_ust_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.00036365269665540557
# intercept:263.8001646488123
# r²:-0.06186526411810694
# ##### Computing numeric col: ag_reparaturkost_netto_lw
# ##### Date col: gutschriftsdatum
# ! moved by -4.99 to correct for negative values
# slope: 0.00044500293163083005
# intercept:-323.0089500496122
# r²:0.04952743152909385
# ##### Computing numeric col: ag_neben_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -3.941220830071264e-05
# intercept:31.074948086009005
# r²:-0.006076493278697063
# ##### Computing numeric col: ag_plop_lw
# ##### Date col: gutschriftsdatum
# ! moved by -30.05 to correct for negative values
# slope: 0.0002550792060278496
# intercept:-183.79826120221108
# r²:0.04328477877645183
# ##### Computing numeric col: accmgr_fallzaehler
# ##### Date col: gutschriftsdatum
# ! moved by -1.0 to correct for negative values
# slope: -0.000244804285814632
# intercept:180.91065639652916
# r²:-0.07637869975323365
# ##### Computing numeric col: accmgr_anz_teile
# ##### Date col: gutschriftsdatum
# ! moved by -23.0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: accmgr_sum_az
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: 0.0005158116341619619
# intercept:-387.62329488710776
# r²:0.053163882921565896
# ##### Computing numeric col: accmgr_sum_aw_p_az
# ##### Date col: gutschriftsdatum
# ! moved by -3.0 to correct for negative values
# slope: 2.312584180625705e-06
# intercept:0.2680930315772452
# r²:0.0007579166011561807
# ##### Computing numeric col: accmgr_kost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by -836.53 to correct for negative values
# slope: -0.00010513212213159658
# intercept:84.27899366032926
# r²:-0.04872083604120608
# ##### Computing numeric col: accmgr_kost_aw_p_az_eur
# ##### Date col: gutschriftsdatum
# ! moved by -22.58 to correct for negative values
# slope: 0.00019890750533602095
# intercept:-142.47990643730418
# r²:0.0650429339616576
# ##### Computing numeric col: accmgr_teilekost_m_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by -323.89 to correct for negative values
# slope: -1.0490007398008206e-05
# intercept:13.659140443569093
# r²:-0.004553829112255835
# ##### Computing numeric col: accmgr_teilekost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by -301.29 to correct for negative values
# slope: -1.0060314206583364e-05
# intercept:13.263425718627929
# r²:-0.004457637317041139
# ##### Computing numeric col: accmgr_hc_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -22.6 to correct for negative values
# slope: -4.924360020810097e-05
# intercept:39.5513910983624
# r²:-0.01914203650473613
# ##### Computing numeric col: accmgr_fremdl_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -836.53 to correct for negative values
# slope: -0.0001525552917679601
# intercept:119.0869256199991
# r²:-0.06896719366489083
# ##### Computing numeric col: accmgr_reparaturkost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -836.53 to correct for negative values
# slope: -0.0001059088944975736
# intercept:84.85860486528959
# r²:-0.048533561712964454
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ##### Computing numeric col: accmgr_plop_eur
# ##### Date col: gutschriftsdatum
# ! moved by -104.95 to correct for negative values
# slope: 0.00010903315140999949
# intercept:-75.54307308812086
# r²:0.04742523931788252
# ##### Computing numeric col: accmgr_kost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by -170625.0 to correct for negative values
# slope: -6.678141044767469e-05
# intercept:61.26352971305673
# r²:-0.03373529682171851
# ##### Computing numeric col: accmgr_kost_aw_p_az_lw
# ##### Date col: gutschriftsdatum
# ! moved by -19425.0 to correct for negative values
# slope: -3.3856617551637935e-05
# intercept:34.872067635829374
# r²:-0.01569159302238236
# ##### Computing numeric col: accmgr_teilekost_m_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by -27700.0 to correct for negative values
# slope: 1.3465833327147832e-05
# intercept:0.38162135302236244
# r²:0.005907336446861849
# ##### Computing numeric col: accmgr_teilekost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by -27700.0 to correct for negative values
# slope: 1.311358050579805e-05
# intercept:0.6387991008314433
# r²:0.005786484045279266
# ##### Computing numeric col: accmgr_hc_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -176.92 to correct for negative values
# slope: -4.574421059981547e-05
# intercept:39.040227698036276
# r²:-0.015278385797652753
# ##### Computing numeric col: accmgr_fremdl_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -123500.0 to correct for negative values
# slope: -0.000181550731223229
# intercept:145.4303145771117
# r²:-0.08117866144562937
# ##### Computing numeric col: accmgr_reparaturkost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -170625.0 to correct for negative values
# slope: -6.596179621583057e-05
# intercept:60.66077725967716
# r²:-0.03334118632697291
# ##### Computing numeric col: accmgr_plop_lw
# ##### Date col: gutschriftsdatum
# ! moved by -18192.54 to correct for negative values
# slope: 2.8756116321565794e-05
# intercept:-11.318975245763715
# r²:0.013016573505017753
# ##### Computing numeric col: subs_kost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by -836.53 to correct for negative values
# slope: -8.95732674685774e-05
# intercept:72.73927580724362
# r²:-0.0438348766380158
# ##### Computing numeric col: subs_kost_aw_p_az_eur
# ##### Date col: gutschriftsdatum
# ! moved by -32.24 to correct for negative values
# slope: 0.00012377302770763822
# intercept:-87.43583891915084
# r²:0.04825766814670227
# ##### Computing numeric col: subs_teilekost_m_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by -323.89 to correct for negative values
# slope: -6.209531891677448e-06
# intercept:10.413353109066556
# r²:-0.0029936432744331128
# ##### Computing numeric col: subs_teilekost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by -301.29 to correct for negative values
# slope: -1.1687963342100173e-05
# intercept:14.377190861918198
# r²:-0.00566478832017866
# ##### Computing numeric col: subs_hc_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -22.6 to correct for negative values
# slope: 6.292087565020015e-06
# intercept:-1.4763810402048558
# r²:0.0029922006645361652
# ##### Computing numeric col: subs_fremdl_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -836.53 to correct for negative values
# slope: -0.00013229408024776802
# intercept:104.15408245103595
# r²:-0.061377341653866914
# ##### Computing numeric col: subs_reparaturkost_eur
# ##### Date col: gutschriftsdatum
# ! moved by -836.53 to correct for negative values
# slope: -8.590395090901656e-05
# intercept:70.04016393122822
# r²:-0.041829454082061346
# ##### Computing numeric col: subs_kost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by -170625.0 to correct for negative values
# slope: -0.0001264432203543599
# intercept:105.17755598948358
# r²:-0.06616720914799237
# ##### Computing numeric col: subs_kost_aw_p_az_lw
# ##### Date col: gutschriftsdatum
# ! moved by -19425.0 to correct for negative values
# slope: -0.00012918742300350384
# intercept:105.02088524285752
# r²:-0.06560484567290055
# ##### Computing numeric col: subs_teilekost_m_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by -48139.0 to correct for negative values
# slope: -9.406996327727419e-05
# intercept:80.08148876167789
# r²:-0.049863898312177884
# ##### Computing numeric col: subs_teilekost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by -48139.0 to correct for negative values
# slope: -9.442492863682552e-05
# intercept:80.3441222923652
# r²:-0.050049734152092795
# ##### Computing numeric col: subs_hc_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -3357.0 to correct for negative values
# slope: 8.816551287606844e-05
# intercept:-56.82610374897134
# r²:0.044120570897269014
# ##### Computing numeric col: subs_fremdl_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -123500.0 to correct for negative values
# slope: -0.00018072172917637345
# intercept:144.81419351423352
# r²:-0.07816709763052562
# ##### Computing numeric col: subs_reparaturkost_lw
# ##### Date col: gutschriftsdatum
# ! moved by -170625.0 to correct for negative values
# slope: -0.00012460530671415932
# intercept:103.82534361040773
# r²:-0.0655891342777169
# ##### Computing numeric col: mp_kost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0006006366155328069
# intercept:437.98671101624194
# r²:-0.07061392748885886
# ##### Computing numeric col: mp_kost_aw_p_az_eur
# ##### Date col: gutschriftsdatum
# ! moved by -0.02 to correct for negative values
# slope: -0.0004439173377124501
# intercept:323.5249301085811
# r²:-0.06791167160710032
# ##### Computing numeric col: mp_teilekost_m_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0003989405154135049
# intercept:288.9904181834107
# r²:-0.06705817025417272
# ##### Computing numeric col: mp_teilekost_o_nk_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0003990666719433642
# intercept:289.0838916323839
# r²:-0.06697626596202097
# ##### Computing numeric col: mp_hc_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -6.85377850701433e-06
# intercept:-7.278709600193942
# r²:-0.002986452561113639
# ##### Computing numeric col: mp_fremdl_kost_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: mp_reparaturkost_eur
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0006005099597977347
# intercept:437.8928676899977
# r²:-0.07064895494287625
# ##### Computing numeric col: mp_kost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0005651884893475984
# intercept:414.48365454648746
# r²:-0.07882399131821861
# ##### Computing numeric col: mp_kost_aw_p_az_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0006456450011218527
# intercept:471.5788017754651
# r²:-0.07834029677520395
# ##### Computing numeric col: mp_teilekost_m_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0003712570634846046
# intercept:271.2773917805782
# r²:-0.06886147756707647
# ##### Computing numeric col: mp_teilekost_o_nk_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0003713825316211133
# intercept:271.3703551766765
# r²:-0.06875514985865981
# ##### Computing numeric col: mp_hc_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -6.85377850701433e-06
# intercept:-4.535621542350858
# r²:-0.002986452561113639
# ##### Computing numeric col: mp_fremdl_kost_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: mp_reparaturkost_lw
# ##### Date col: gutschriftsdatum
# ! moved by 0.0 to correct for negative values
# slope: -0.0005650630391075123
# intercept:414.39070441042685
# r²:-0.07888609564716965
# ##### Computing numeric col: befundnummer_treffer
# ##### Date col: gutschriftsdatum
# slope: -0.0009082573024403764
# intercept:685.9692290428992
# r²:-0.10148881831042063
# ##### Computing numeric col: vfc_id_fo
# ##### Date col: gutschriftsdatum
# slope: -4.781738564052826e-05
# intercept:45.04661133375434
# r²:-0.0449135472882879
# ####### The datetime column line_nr: has less than 4 chars --> not used as datetime column.
# ####### The datetime column version: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ist_lokale_reparatur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column gw_kulanzstufe: has less than 4 chars --> not used as datetime column.
# ####### The datetime column gw_kulanzstufe_lokal: has less than 4 chars --> not used as datetime column.
# ####### The datetime column gw_kulanzstufe_zentral: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mixed_stage: has less than 4 chars --> not used as datetime column.
# ####### The datetime column fahrzeugart: has less than 4 chars --> not used as datetime column.
# ####### Datetime column gw_befundnummer: conversion error!
# ####### Datetime column befund_bereinigt: conversion error!
# ####### The datetime column befund_kategorie: has less than 4 chars --> not used as datetime column.
# ####### The datetime column eingereichter_befund: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mandant_iso_land: has less than 4 chars --> not used as datetime column.
# ####### The datetime column abschlepp_kz: has less than 4 chars --> not used as datetime column.
# ####### The datetime column freigabeart: has less than 4 chars --> not used as datetime column.
# ####### The datetime column freigabenr: has less than 4 chars --> not used as datetime column.
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:60: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:60: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ####### The datetime column teilfreigabe_id: has less than 4 chars --> not used as datetime column.
# ####### The datetime column freigabe_angewendet: has less than 4 chars --> not used as datetime column.
# ####### The datetime column kontonummer: has less than 4 chars --> not used as datetime column.
# ####### The datetime column antragstellerkommentar: has less than 4 chars --> not used as datetime column.
# ####### The datetime column assessor_kommentar: has less than 4 chars --> not used as datetime column.
# ####### The datetime column arbeitspaketnummer: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ist_abgasrelevant: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ist_best_reparatur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mixed_repair: has less than 4 chars --> not used as datetime column.
# ####### The datetime column addon_indikator: has less than 4 chars --> not used as datetime column.
# ####### The datetime column dcs_herkunftsindikator: has less than 4 chars --> not used as datetime column.
# ####### The datetime column korrekturbeschreibung: has less than 4 chars --> not used as datetime column.
# ####### The datetime column reklamationsbeschreibung: has less than 4 chars --> not used as datetime column.
# ####### The datetime column technische_anmerkungen: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ursachenbeschreibung: has less than 4 chars --> not used as datetime column.
# ####### The datetime column service_techniker_id: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_verlagerung_anteil: has less than 4 chars --> not used as datetime column.
# ####### The datetime column kostenstelle: has less than 4 chars --> not used as datetime column.
# ####### The datetime column abrechnungstyp: has less than 4 chars --> not used as datetime column.
# ####### The datetime column graumarkt: has less than 4 chars --> not used as datetime column.
# ####### The datetime column hoechstwert_id_vg: has less than 4 chars --> not used as datetime column.
# ####### The datetime column hoechstwert_id_ag: has less than 4 chars --> not used as datetime column.
# ####### The datetime column hoechstwert_id_res: has less than 4 chars --> not used as datetime column.
# ####### The datetime column hoechstwert_id_ext: has less than 4 chars --> not used as datetime column.
# ####### The datetime column hoechstwert_id_mvg: has less than 4 chars --> not used as datetime column.
# ####### The datetime column stnb_code: has less than 4 chars --> not used as datetime column.
# ####### The datetime column schattenschluessel: has less than 4 chars --> not used as datetime column.
# ####### The datetime column elos_nummer: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_fallzaehler: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_anz_teile: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_sum_az: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_sum_aw_p_az: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_aw_p_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_aw_p_az_ust_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_aw_p_az_netto_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_m_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_m_nk_ust_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_m_nk_netto_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_rs_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hc_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hc_kost_ust_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hc_kost_netto_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_ust_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_netto_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_ust_basis_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_keine_ust_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_fremdl_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_fremdl_kost_ust_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_fremdl_kost_netto_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_reparaturkost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_reparaturkost_ust_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_reparaturkost_netto_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_neben_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hk_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_plop_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_aw_p_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_aw_p_az_ust_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_kost_aw_p_az_netto_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_m_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_m_nk_ust_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_m_nk_netto_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_teilekost_rs_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hc_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hc_kost_ust_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hc_kost_netto_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_ust_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_netto_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_ust_basis_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_lc_kost_keine_ust_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_fremdl_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_fremdl_kost_ust_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_fremdl_kost_netto_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_reparaturkost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_reparaturkost_ust_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_reparaturkost_netto_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_neben_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_hk_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column ag_plop_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_fallzaehler: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_anz_teile: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_sum_az: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_sum_aw_p_az: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_kost_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_kost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_kost_aw_p_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_teilekost_m_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_teilekost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_teilekost_rs_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_hc_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_fremdl_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_reparaturkost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_plop_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_kost_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_kost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_kost_aw_p_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_teilekost_m_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_teilekost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_teilekost_rs_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_hc_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_fremdl_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_reparaturkost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column accmgr_plop_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_de_hist_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_de_hist_plop_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_vg_hist_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_vg_hist_plop_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_kost_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_kost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_kost_aw_p_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_teilekost_m_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_teilekost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_hc_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_fremdl_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_reparaturkost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_vg_hist_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_vg_hist_plop_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_kost_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_kost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_kost_aw_p_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_teilekost_m_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_teilekost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_hc_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_fremdl_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column subs_reparaturkost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_kost_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_kost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_kost_aw_p_az_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_teilekost_m_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_teilekost_o_nk_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_hc_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_fremdl_kost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_reparaturkost_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_kost_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_kost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_kost_aw_p_az_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_teilekost_m_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_teilekost_o_nk_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_hc_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_fremdl_kost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column mp_reparaturkost_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column vg_plop_eur: has less than 4 chars --> not used as datetime column.
# ####### The datetime column vg_plop_lw: has less than 4 chars --> not used as datetime column.
# ####### The datetime column aenderungsart: has less than 4 chars --> not used as datetime column.
# ####### The datetime column: ladezeitpunkt is used as datetimecol!
# 734138.0
# 737037.0
# 736167.3
# (1000, 141)
# (410, 141)
# ##### Computing numeric col: Unnamed: 0
# ##### Date col: ladezeitpunkt
# slope: -2.398145231712438e-05
# intercept:23.54740843070556
# r²:-0.006225418416298644
# ##### Computing numeric col: antrag_id
# ##### Date col: ladezeitpunkt
# slope: 0.00015688861929089853
# intercept:-96.18610572892337
# r²:0.9795974422194008
# ##### Computing numeric col: line_nr
# ##### Date col: ladezeitpunkt
# slope: -0.00015165396282857782
# intercept:112.29691889447078
# r²:-0.061250901255991176
# ##### Computing numeric col: version
# ##### Date col: ladezeitpunkt
# slope: -4.694003708238226e-05
# intercept:35.14188653288033
# r²:-0.0316085122899047
# ##### Computing numeric col: ist_lokale_reparatur
# ##### Date col: ladezeitpunkt
# ! moved by 0 to correct for negative values
# slope: -0.0006865442825578255
# intercept:499.1143863685682
# r²:-0.030919546696983692
# ##### Computing numeric col: gw_kulanzstufe
# ##### Date col: ladezeitpunkt
# slope: -9.101227212097657e-05
# intercept:68.47125885947327
# r²:-0.026454721174989385
# ##### Computing numeric col: gw_kulanzstufe_lokal
# ##### Date col: ladezeitpunkt
# slope: -3.985458403398657e-05
# intercept:30.785613764001482
# r²:-0.01156781535526765
# ##### Computing numeric col: gw_kulanzstufe_zentral
# ##### Date col: ladezeitpunkt
# slope: -8.236441458191928e-05
# intercept:62.09892066286477
# r²:-0.02390506883191615
# ##### Computing numeric col: mixed_stage
# ##### Date col: ladezeitpunkt
# ! moved by 0.0 to correct for negative values
# slope: 0.00040677182536776247
# intercept:-310.99408066201784
# r²:0.07977011127345252
# ##### Computing numeric col: fahrzeugart
# ##### Date col: ladezeitpunkt
# ! moved by 0 to correct for negative values
# slope: -0.00016505969470629312
# intercept:121.4156376475009
# r²:-0.03061908784177724
# ##### Computing numeric col: freigabe_angewendet
# ##### Date col: ladezeitpunkt
# ! moved by 0 to correct for negative values
# slope: -4.181889913321967e-06
# intercept:-8.376355849172109
# r²:-0.0013370419561400317
# ##### Computing numeric col: ist_best_reparatur
# ##### Date col: ladezeitpunkt
# ! moved by 0 to correct for negative values
# slope: -0.0013333897675420758
# intercept:978.0282210091368
# r²:-0.06184336804288201
# ##### Computing numeric col: mixed_repair
# ##### Date col: ladezeitpunkt
# ! moved by 0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: hoechstwert_id_vg
# ##### Date col: ladezeitpunkt
# slope: -0.0004859294415437503
# intercept:369.9239017568077
# r²:-0.03974725782792662
# ##### Computing numeric col: hoechstwert_id_ag
# ##### Date col: ladezeitpunkt
# slope: 0.0007932409488990139
# intercept:-576.9698998359901
# r²:0.03199361269870968
# ##### Computing numeric col: hoechstwert_id_res
# ##### Date col: ladezeitpunkt
# slope: 0.0
# intercept:0.0
# r²:0.0
# ##### Computing numeric col: hoechstwert_id_ext
# ...
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: 4.799598128356204e-05
# intercept:-43.71175122533125
# r²:0.02081558703771289
# ##### Computing numeric col: ag_hc_kost_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: 9.366261009666275e-05
# intercept:-67.6610772043599
# r²:0.014570320522762017
# ##### Computing numeric col: ag_hc_kost_ust_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -2.921122112671551e-05
# intercept:15.019630345667743
# r²:-0.0061257239489546055
# ##### Computing numeric col: ag_hc_kost_netto_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: 9.457686606759303e-05
# intercept:-68.3369612004832
# r²:0.014758174854738496
# ##### Computing numeric col: ag_lc_kost_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: 2.029830354476754e-05
# intercept:-13.729052660568394
# r²:0.003345747173016938
# ##### Computing numeric col: ag_lc_kost_ust_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -3.629301032140232e-05
# intercept:20.115420272840872
# r²:-0.00753263798553834
# ##### Computing numeric col: ag_lc_kost_netto_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: 2.1242753025595375e-05
# intercept:-14.427178783423123
# r²:0.003513926850832098
# ##### Computing numeric col: ag_lc_kost_ust_basis_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -3.47324129223756e-05
# intercept:20.73809611316714
# r²:-0.0071961342484951904
# ##### Computing numeric col: ag_lc_kost_keine_ust_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: 4.625642934908142e-06
# intercept:-2.250289739242048
# r²:0.0008032451253290808
# ##### Computing numeric col: ag_fremdl_kost_lw
# ##### Date col: deltakey_ts
# ! moved by -4.99 to correct for negative values
# slope: -0.00011755970944178623
# intercept:88.85022929505772
# r²:-0.020458769130622504
# ##### Computing numeric col: ag_fremdl_kost_ust_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -3.1370394519629706e-05
# intercept:18.223574854531414
# r²:-0.011747633730210927
# ##### Computing numeric col: ag_fremdl_kost_netto_lw
# ##### Date col: deltakey_ts
# ! moved by -4.99 to correct for negative values
# slope: -0.00011744291171734017
# intercept:88.7634691444535
# r²:-0.02046903329861398
# ##### Computing numeric col: ag_reparaturkost_lw
# ##### Date col: deltakey_ts
# ! moved by -4.99 to correct for negative values
# slope: 0.0004638454620305198
# intercept:-336.8888499932851
# r²:0.05171638900957723
# ##### Computing numeric col: ag_reparaturkost_ust_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.0003551984006376234
# intercept:257.57192705988734
# r²:-0.06066765116158744
# ##### Computing numeric col: ag_reparaturkost_netto_lw
# ##### Date col: deltakey_ts
# ! moved by -4.99 to correct for negative values
# slope: 0.0004683347639258456
# intercept:-340.1989318161433
# r²:0.05230405883035061
# ##### Computing numeric col: ag_neben_kost_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -3.0301812295220674e-05
# intercept:24.36272952037121
# r²:-0.004689913881949729
# ##### Computing numeric col: ag_plop_lw
# ##### Date col: deltakey_ts
# ! moved by -30.05 to correct for negative values
# slope: 0.0002623398748327229
# intercept:-189.147711711327
# r²:0.044688571359610005
# ##### Computing numeric col: accmgr_fallzaehler
# ##### Date col: deltakey_ts
# ! moved by -1.0 to correct for negative values
# slope: -0.00024662615444995294
# intercept:182.2528056517932
# r²:-0.07725428141053424
# ##### Computing numeric col: accmgr_anz_teile
# ##### Date col: deltakey_ts
# ! moved by -23.0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: accmgr_sum_az
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: 0.0005224556166042527
# intercept:-392.51870040921534
# r²:0.054056105192384324
# ##### Computing numeric col: accmgr_sum_aw_p_az
# ##### Date col: deltakey_ts
# ! moved by -3.0 to correct for negative values
# slope: 6.964093830109762e-06
# intercept:-3.159156654536921
# r²:0.0022907509381961265
# ##### Computing numeric col: accmgr_kost_o_nk_eur
# ##### Date col: deltakey_ts
# ! moved by -836.53 to correct for negative values
# slope: -0.0001025177604967442
# intercept:82.35293456308263
# r²:-0.04769635227195833
# ##### Computing numeric col: accmgr_kost_aw_p_az_eur
# ##### Date col: deltakey_ts
# ! moved by -22.58 to correct for negative values
# slope: 0.0002069004968031518
# intercept:-148.36905839638084
# r²:0.06786902185583175
# ##### Computing numeric col: accmgr_teilekost_m_nk_eur
# ##### Date col: deltakey_ts
# ! moved by -323.89 to correct for negative values
# slope: -7.909361054425427e-06
# intercept:11.75781786062435
# r²:-0.00344695807883243
# ##### Computing numeric col: accmgr_teilekost_o_nk_eur
# ##### Date col: deltakey_ts
# ! moved by -301.29 to correct for negative values
# slope: -7.537134263103854e-06
# intercept:11.40445162031089
# r²:-0.0033527024276678503
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# ##### Computing numeric col: accmgr_hc_kost_eur
# ##### Date col: deltakey_ts
# ! moved by -22.6 to correct for negative values
# slope: -4.671948718693035e-05
# intercept:37.691666127106515
# r²:-0.01823199083935092
# ##### Computing numeric col: accmgr_fremdl_kost_eur
# ##### Date col: deltakey_ts
# ! moved by -836.53 to correct for negative values
# slope: -0.00015139709359004663
# intercept:118.2337375020041
# r²:-0.06873047588726819
# ##### Computing numeric col: accmgr_reparaturkost_eur
# ##### Date col: deltakey_ts
# ! moved by -836.53 to correct for negative values
# slope: -0.000103192779679952
# intercept:82.85757453202115
# r²:-0.04747483617354373
# ##### Computing numeric col: accmgr_plop_eur
# ##### Date col: deltakey_ts
# ! moved by -104.95 to correct for negative values
# slope: 0.00011035106511714986
# intercept:-76.51410211776495
# r²:0.04818769277771283
# ##### Computing numeric col: accmgr_kost_o_nk_lw
# ##### Date col: deltakey_ts
# ! moved by -170625.0 to correct for negative values
# slope: -6.727437070038244e-05
# intercept:61.626549861224106
# r²:-0.03411944712947891
# ##### Computing numeric col: accmgr_kost_aw_p_az_lw
# ##### Date col: deltakey_ts
# ! moved by -19425.0 to correct for negative values
# slope: -3.40150046995753e-05
# intercept:34.98857617971136
# r²:-0.015826968708311247
# ##### Computing numeric col: accmgr_teilekost_m_nk_lw
# ##### Date col: deltakey_ts
# ! moved by -27700.0 to correct for negative values
# slope: 1.3461102317537611e-05
# intercept:0.3849264395398482
# r²:0.005928736773573925
# ##### Computing numeric col: accmgr_teilekost_o_nk_lw
# ##### Date col: deltakey_ts
# ! moved by -27700.0 to correct for negative values
# slope: 1.3060251585024329e-05
# intercept:0.6779073214668045
# r²:0.005785867937294213
# ##### Computing numeric col: accmgr_hc_kost_lw
# ##### Date col: deltakey_ts
# ! moved by -176.92 to correct for negative values
# slope: -4.2673790822009186e-05
# intercept:36.778092636945985
# r²:-0.014308990361960108
# ##### Computing numeric col: accmgr_fremdl_kost_lw
# ##### Date col: deltakey_ts
# ! moved by -123500.0 to correct for negative values
# slope: -0.00018246942610796333
# intercept:146.1069800613951
# r²:-0.08193129896943517
# ##### Computing numeric col: accmgr_reparaturkost_lw
# ##### Date col: deltakey_ts
# ! moved by -170625.0 to correct for negative values
# slope: -6.643486553606565e-05
# intercept:61.009143607033316
# r²:-0.033713816863300695
# ##### Computing numeric col: accmgr_plop_lw
# ##### Date col: deltakey_ts
# ! moved by -18192.54 to correct for negative values
# slope: 2.8337610187605172e-05
# intercept:-11.01082739772647
# r²:0.012878224545471207
# ##### Computing numeric col: subs_kost_o_nk_eur
# ##### Date col: deltakey_ts
# ! moved by -836.53 to correct for negative values
# slope: -8.845811009884398e-05
# intercept:71.9177524967721
# r²:-0.04346277633624623
# ##### Computing numeric col: subs_kost_aw_p_az_eur
# ##### Date col: deltakey_ts
# ! moved by -32.24 to correct for negative values
# slope: 0.0001228301182808354
# intercept:-86.74133260292491
# r²:0.04808037107783698
# ##### Computing numeric col: subs_teilekost_m_nk_eur
# ##### Date col: deltakey_ts
# ! moved by -323.89 to correct for negative values
# slope: -5.562762322972644e-06
# intercept:9.936786100688881
# r²:-0.002692603138405306
# ##### Computing numeric col: subs_teilekost_o_nk_eur
# ##### Date col: deltakey_ts
# ! moved by -301.29 to correct for negative values
# slope: -1.0952524454200523e-05
# intercept:13.835304846911058
# r²:-0.0053296598895951905
# ##### Computing numeric col: subs_hc_kost_eur
# ##### Date col: deltakey_ts
# ! moved by -22.6 to correct for negative values
# slope: 6.364659317203843e-06
# intercept:-1.5299367273871773
# r²:0.0030388932627316637
# ##### Computing numeric col: subs_fremdl_kost_eur
# ##### Date col: deltakey_ts
# ! moved by -836.53 to correct for negative values
# slope: -0.00013140984771943084
# intercept:103.50273953024238
# r²:-0.06122487814262242
# ##### Computing numeric col: subs_reparaturkost_eur
# ##### Date col: deltakey_ts
# ! moved by -836.53 to correct for negative values
# slope: -8.476427110479145e-05
# intercept:69.2005698144477
# r²:-0.04144002585988754
# ##### Computing numeric col: subs_kost_o_nk_lw
# ##### Date col: deltakey_ts
# ! moved by -170625.0 to correct for negative values
# slope: -0.00012712455046963526
# intercept:105.67939229470609
# r²:-0.06679066144889965
# ##### Computing numeric col: subs_kost_aw_p_az_lw
# ##### Date col: deltakey_ts
# ! moved by -19425.0 to correct for negative values
# slope: -0.00013016078664374611
# intercept:105.737851965458
# r²:-0.0663621094371757
# ##### Computing numeric col: subs_teilekost_m_nk_lw
# ##### Date col: deltakey_ts
# ! moved by -48139.0 to correct for negative values
# slope: -9.314048330966892e-05
# intercept:79.3967621519963
# r²:-0.049570239489156405
# ##### Computing numeric col: subs_teilekost_o_nk_lw
# ##### Date col: deltakey_ts
# ! moved by -48139.0 to correct for negative values
# slope: -9.347114792830116e-05
# intercept:79.64149252249322
# r²:-0.04974391041045769
# ##### Computing numeric col: subs_hc_kost_lw
# ##### Date col: deltakey_ts
# ! moved by -3357.0 to correct for negative values
# slope: 8.761815767484613e-05
# intercept:-56.422868594991385
# r²:0.04402343051146648
# ##### Computing numeric col: subs_fremdl_kost_lw
# ##### Date col: deltakey_ts
# ! moved by -123500.0 to correct for negative values
# slope: -0.0001817789052908952
# intercept:145.59289398734134
# r²:-0.07895670008568327
# ##### Computing numeric col: subs_reparaturkost_lw
# ##### Date col: deltakey_ts
# ! moved by -170625.0 to correct for negative values
# slope: -0.0001252553274172719
# intercept:104.30411413501992
# r²:-0.06619583573970908
# ##### Computing numeric col: mp_kost_o_nk_eur
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.0005994582416396937
# intercept:437.1190031624297
# r²:-0.07055538790113221
# ##### Computing numeric col: mp_kost_aw_p_az_eur
# ##### Date col: deltakey_ts
# ! moved by -0.02 to correct for negative values
# slope: -0.0004428953010705516
# intercept:322.7723060843051
# r²:-0.0678322262521979
# ##### Computing numeric col: mp_teilekost_m_nk_eur
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.00039874516643243564
# intercept:288.8467136723243
# r²:-0.06710141388495607
# ##### Computing numeric col: mp_teilekost_o_nk_eur
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.0003988666300591932
# intercept:288.93673037297447
# r²:-0.0670186786403905
# ##### Computing numeric col: mp_hc_kost_eur
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -6.598824455505459e-06
# intercept:-7.466506358594661
# r²:-0.002878623161486224
# ##### Computing numeric col: mp_fremdl_kost_eur
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: mp_reparaturkost_eur
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.0005993362973776826
# intercept:437.02863026296603
# r²:-0.0705909119761395
# ##### Computing numeric col: mp_kost_o_nk_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.000563673150035886
# intercept:413.3677199110659
# r²:-0.07870188722939253
# ##### Computing numeric col: mp_kost_aw_p_az_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.000643732037494693
# intercept:470.17001407136536
# r²:-0.07819684451819538
# ##### Computing numeric col: mp_teilekost_m_nk_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.0003709272635491099
# intercept:271.0346370370419
# r²:-0.06887840036302569
# ##### Computing numeric col: mp_teilekost_o_nk_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.000371048064390096
# intercept:271.12416254711934
# r²:-0.06877120213125186
# ##### Computing numeric col: mp_hc_kost_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -6.598824455505459e-06
# intercept:-4.723418300751578
# r²:-0.002878623161486224
# ##### Computing numeric col: mp_fremdl_kost_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: nan
# intercept:nan
# r²:nan
# ##### Computing numeric col: mp_reparaturkost_lw
# ##### Date col: deltakey_ts
# ! moved by 0.0 to correct for negative values
# slope: -0.0005635523664255925
# intercept:413.2782071706556
# r²:-0.07876450057310233
# ##### Computing numeric col: befundnummer_treffer
# ##### Date col: deltakey_ts
# slope: -0.0009208478582114154
# intercept:695.2466510103759
# r²:-0.10329290633445858
# ##### Computing numeric col: vfc_id_fo
# ##### Date col: deltakey_ts
# slope: -4.706251278103745e-05
# intercept:44.490460424430665
# r²:-0.044381026495054765
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:60: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:60: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#    tablename           datecol   valuecol  analyzed_fraction       exponent  \
# 1  Testtable     ladezeitpunkt  antrag_id                0.3  412574.395030
# 2  Testtable       deltakey_ts  antrag_id                0.3  412574.395030
# 0  Testtable  gutschriftsdatum  antrag_id                0.3  406784.983836
#
#    r_squared
# 1   0.979597
# 2   0.979597
# 0   0.998908

# %% [markdown]
# ## Run multiple queries with different parameters but add them up to one result dataframe

# %%
firstrow=True
for fraction in [1,0.5,0.25]:
    temptable=find_exponents(sqlDFTest,
                           fractionToAnalyze=fraction,
                           outputPath='outputs',
                           outputTable=False,
                           outputPlots=False,
                           outputTablename='Testtable',
                           logToScreen=False,
                           columnFillThreshold=0.5,
                           exp_treshold=0.6,
                           r_treshold=0.7,
                           maxrows=5000)
    if firstrow:
        resulttable=temptable
        firstrow=False
    else:
        resulttable=resulttable.append(temptable)
        
resulttable
# Out:
# False
# 0
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# False
# 0
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# ...
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:63: RuntimeWarning: divide by zero encountered in log
# C:\Anaconda3\lib\site-packages\numpy\lib\function_base.py:2445: RuntimeWarning: invalid value encountered in subtract
#   X -= avg[:, None]
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:879: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1818: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)
#    tablename           datecol   valuecol analyzed_fraction       exponent  \
# 0  Testtable  gutschriftsdatum  antrag_id                 1  375100.184833
# 1  Testtable     ladezeitpunkt  antrag_id                 1  374501.571608
# 2  Testtable       deltakey_ts  antrag_id                 1  374501.571608
# 1  Testtable     ladezeitpunkt  antrag_id               0.5  403706.156264
# 2  Testtable       deltakey_ts  antrag_id               0.5  403706.156264
# 0  Testtable  gutschriftsdatum  antrag_id               0.5  392123.592223
# 0  Testtable  gutschriftsdatum  antrag_id              0.25  411146.922172
# 1  Testtable     ladezeitpunkt  antrag_id              0.25  410639.939745
# 2  Testtable       deltakey_ts  antrag_id              0.25  410639.939745
#
#    r_squared
# 0   0.999400
# 1   0.994495
# 2   0.994495
# 1   0.975731
# 2   0.975731
# 0   0.999374
# 0   0.998433
# 1   0.998503
# 2   0.998503
